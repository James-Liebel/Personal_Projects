# %%
# Write your code here

import math
import sympy
from sympy import symbols
from sympy.solvers import solve
import numpy_financial as npf

def annuity():
  p=float(input('starting amount:'))
  r=float(input('percent increase as a decimal:'))
  t=int(input('years compounded:'))
  n=int(input('number of times compounded per year'))

  return p*(1+r/n)**(r*t)

def mortgage_payment():
  p=float(input('starting amount:'))
  r=float(input('percent increase as a decimal:'))
  t=int(input('years compounded:'))
  n=int(input('number of times compounded per year'))

  return p*((r/12*(1+r/12)**(12*t))/((1+r/12)**(12*t)-1))

def retirement_investment():
  until=int(input('how long until you retire:'))
  retired=int(input('how long will you be retired:'))
  cost=int(input('yealry cost of retirement:'))
  returns=float(input('expected return on investment as a decimal:'))

  second_num=npf.fv(rate=returns,nper=retired,pmt=cost,pv=0)
  print(second_num)
  return npf.pmt(rate=returns,nper=until,pv=0,fv=second_num)




def double():
  r=float(input("what is the percent as a decimal:"))

  return str(math.log(2,1+r))+' years'

def log():
  base = float(input("base: "))
  result = float(input("result: "))

  # Just change the next line:
  exp = math.log(result,base)
  return exp

def scientific():
  decider=input('to(t) or from(f) scientific notation')
  if decider==('t'):
    num=float(input('what num'))
    return f"{num:.6e}"

  elif decider==('f'):
    num=float(input('what num'))
    return f"{num:.6f}"

# This step does not have a test
