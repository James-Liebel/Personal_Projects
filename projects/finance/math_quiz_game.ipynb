# %%
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sympy
from sympy import symbols
from sympy.solvers import solve
from ipywidgets import interact,interactive


xmin=-10
xmax=10
ymin=-10
ymax=10

def scat_game():
  difficulty=input('make difficult(d)?')
  if difficulty =='d':
    global xmin,xmax,ymin,ymax
    xmin=-20
    xmax=20
    ymin=-20
    ymax=20


  points = 2*(xmax-xmin)
  x = np.linspace(xmin, xmax, points)

  fig, ax = plt.subplots()
  plt.axis([xmin,xmax,ymin,ymax]) # window size
  plt.plot([xmin,xmax],[0,0],'b') # blue x axis
  plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

  ax.set_xlabel("x values")
  ax.set_ylabel("y values")
  ax.set_title("Some Graph")
  ax.grid(True)

  ax.set_xticks(np.arange(xmin, xmax, 1))
  ax.set_yticks(np.arange(ymin, ymax, 1))


  x=[]
  y=[]


  for i in range (5):
    x1=(int(random.random() * (xmax - xmin) + xmin))
    y1=(int(random.random() * (ymax - ymin) + ymin))
    x.append(x1)
    y.append(y1)
    ax.plot([x1], [y1], 'ro',label='Point')

  ax.legend()

  plt.show()
  for _ in range(len(x)):
    x_guess=int(input('what is your x guess:'))
    y_guess=int(input('what is your y guess:'))
    if x_guess in x:
      print("that's right")
      x.remove(x_guess)
    else:
      print('you are wrong')
    if y_guess in y:
      print("that's right")
      y.remove(y_guess)
    else:
      print("you are wrong")

def problem_gen():
  difficulty=input('make it difficult(d)?:')
  if difficulty=='d':
    mult=3
  else:
    mult=1
  first_random_num=int(random.random()*11)*negative*mult
  second_random_num=int(random.random()*11)*negative*mult
  third_random_num=int(random.random()*11)*negative*mult


  x=symbols('x')

  print(f'{first_random_num}*x+{second_random_num}={third_random_num}')
  eq=first_random_num*x+second_random_num-third_random_num
  value=solve(eq,x)
  answer=[input('what is the answer:')]
  print(f"answer is {value}")


def projectile():

  difficulty=input("what difficulty u want,hard(d) or easy(e)")
  if difficulty=='e':

    one = np.linspace(-10, 10,100)
    two = np.linspace(-10, 10,100)
      # Adjusted for broadcasting

      # Set up sliders for 'one' and 'two'
    ip=interactive(function_thing,one=(-10,10), two=(-10,10))
    output=ip.children[-1]
    display(ip)
  elif difficulty=='d':
    #shows the red line grapgh first
    points = 2*(xmax-xmin)
    x = np.linspace(xmin,xmax, 100)

    fig, ax = plt.subplots()
    plt.axis([xmin,xmax,ymin,ymax]) # window size
    plt.plot([xmin,xmax],[0,0],'b') # blue x axis
    plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

    ax.set_xlabel("x values")
    ax.set_ylabel("y values")
    ax.set_title("Some Graph")
    ax.grid(True)

    ax.set_xticks(np.arange(xmin, xmax, 1))
    ax.set_yticks(np.arange(ymin, ymax, 1))


    plt.plot([x_num,x_num],[yfirst,ysecond], 'r')
    plt.show()

    #make guess based on graph
    a=int(input('what is a value:'))
    b=int(input('what is b value:'))
    c=int(input('what is c value:'))
    function_thing(b,c,a)



#sets up global random nums
negative=-1
if random.random()*10%2==0:
    negative=1
x_num=int(random.random()*9*negative)
yfirst=int(random.random()*9*negative)
ysecond=int(random.random()*9)

def function_thing(one,two,a=1):
  points = 2*(xmax-xmin)
  x = np.linspace(xmin,xmax, 100)

  fig, ax = plt.subplots()
  plt.axis([xmin,xmax,ymin,ymax]) # window size
  plt.plot([xmin,xmax],[0,0],'b') # blue x axis
  plt.plot([0,0],[ymin,ymax], 'b') # blue y axis

  ax.set_xlabel("x values")
  ax.set_ylabel("y values")
  ax.set_title("Some Graph")
  ax.grid(True)

  ax.set_xticks(np.arange(xmin, xmax, 1))
  ax.set_yticks(np.arange(ymin, ymax, 1))
  plt.plot(x,a*(-x**2)+one*x + two,lw=5,color='g')



  plt.plot([x_num,x_num],[yfirst,ysecond], 'r')
  plt.show()

# %%
problem_gen()
